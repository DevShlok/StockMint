# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt
stock = 'AAPL'
start = dt.datetime(2010, 1, 1)
end = dt.datetime(2025, 4 , 25)
df= yf.download(stock, start, end)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.440331  6.455077  6.391278  6.422877  493729600
# 2010-01-05  6.451466  6.487879  6.417460  6.458087  601904800
# 2010-01-06  6.348848  6.477047  6.342227  6.451467  552160000
# 2010-01-07  6.337109  6.379843  6.291066  6.372319  477131200
# 2010-01-08  6.379242  6.379844  6.291369  6.328685  447610800

# %%
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-04-17  196.979996  198.830002  194.419998  197.199997  51334300
# 2025-04-21  193.160004  193.800003  189.809998  193.270004  46742500
# 2025-04-22  199.740005  201.589996  195.970001  196.119995  52976400
# 2025-04-23  204.600006  208.000000  202.800003  206.000000  52929200
# 2025-04-24  208.369995  208.830002  202.940002  204.889999  47311000

# %%
df.shape
# Out:
# (3851, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3851 entries, 2010-01-04 to 2025-04-24
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   3851 non-null   float64
#  1   (High, AAPL)    3851 non-null   float64
#  2   (Low, AAPL)     3851 non-null   float64
#  3   (Open, AAPL)    3851 non-null   float64
#  4   (Volume, AAPL)  3851 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 180.5 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         AAPL         AAPL         AAPL         AAPL          AAPL
# count   3851.000000  3851.000000  3851.000000  3851.000000  3.851000e+03
# mean      70.657603    71.363790    69.878406    70.595961  2.265220e+08
# std       68.598421    69.280195    67.826648    68.515178  2.172253e+08
# min        5.779476     5.898343     5.725306     5.789105  2.323470e+07
# 25%       17.631779    17.850220    17.464922    17.679733  8.329335e+07
# 50%       36.324306    36.536258    36.011482    36.286370  1.372980e+08
# 75%      131.485336   132.774701   130.280519   131.822032  3.026450e+08
# max      258.735504   259.814335   257.347047   257.906429  1.880998e+09

# %%
df=df.reset_index()

# %%
df.head
# Out:
# <bound method NDFrame.head of Price        Date       Close        High         Low        Open     Volume
# Ticker                   AAPL        AAPL        AAPL        AAPL       AAPL
# 0      2010-01-04    6.440331    6.455077    6.391278    6.422877  493729600
# 1      2010-01-05    6.451466    6.487879    6.417460    6.458087  601904800
# 2      2010-01-06    6.348848    6.477047    6.342227    6.451467  552160000
# 3      2010-01-07    6.337109    6.379843    6.291066    6.372319  477131200
# 4      2010-01-08    6.379242    6.379844    6.291369    6.328685  447610800
# ...           ...         ...         ...         ...         ...        ...
# 3846   2025-04-17  196.979996  198.830002  194.419998  197.199997   51334300
# 3847   2025-04-21  193.160004  193.800003  189.809998  193.270004   46742500
# 3848   2025-04-22  199.740005  201.589996  195.970001  196.119995   52976400
# 3849   2025-04-23  204.600006  208.000000  202.800003  206.000000   52929200
# ...

# %%
df.shape
# Out:
# (3851, 6)

# %%
df.columns
# Out:
# MultiIndex([(  'Date',     ''),
#             ( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
#CANDLESTICKS
df.to_csv('Stock.csv')
data1=pd.read_csv('Stock.csv')

# %%
#candlestick chart for Apple

import plotly.graph_objects as go
fig1 = go.Figure(data=[go.Candlestick(x=data1['Date'],
                open=data1['Open'],
                high=data1['High'],
                low=data1['Low'],
                close=data1['Close'])]) 

fig1.update_layout(xaxis_rangeslider_visible=False)
fig1.show()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',     ''),
#             ( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
df=df.drop(['Date'], axis=1)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_20508\1675480993.py:1: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
df.shape
# Out:
# (3851, 5)

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
df.head
# Out:
# <bound method NDFrame.head of Price        Close        High         Low        Open     Volume
# Ticker        AAPL        AAPL        AAPL        AAPL       AAPL
# 0         6.440331    6.455077    6.391278    6.422877  493729600
# 1         6.451466    6.487879    6.417460    6.458087  601904800
# 2         6.348848    6.477047    6.342227    6.451467  552160000
# 3         6.337109    6.379843    6.291066    6.372319  477131200
# 4         6.379242    6.379844    6.291369    6.328685  447610800
# ...            ...         ...         ...         ...        ...
# 3846    196.979996  198.830002  194.419998  197.199997   51334300
# 3847    193.160004  193.800003  189.809998  193.270004   46742500
# 3848    199.740005  201.589996  195.970001  196.119995   52976400
# 3849    204.600006  208.000000  202.800003  206.000000   52929200
# 3850    208.369995  208.830002  202.940002  204.889999   47311000
#
# [3851 rows x 5 columns]>

# %%
df.head()
# Out:
# Price      Close      High       Low      Open     Volume
# Ticker      AAPL      AAPL      AAPL      AAPL       AAPL
# 0       6.440331  6.455077  6.391278  6.422877  493729600
# 1       6.451466  6.487879  6.417460  6.458087  601904800
# 2       6.348848  6.477047  6.342227  6.451467  552160000
# 3       6.337109  6.379843  6.291066  6.372319  477131200
# 4       6.379242  6.379844  6.291369  6.328685  447610800

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label=f'{stock} Closing Price', linewidth=1, color='Green')
plt.title(f'{stock} Closing Price History')
plt.xlabel('Date')
plt.ylabel('Closing Price in USD')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Open'], label=f'{stock} Opening Price', linewidth=1, color='Red')
plt.title(f'{stock} Opening Price History')
plt.xlabel('Date')
plt.ylabel('Opening Price in USD')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Volume'], label=f'{stock} Volume', linewidth=1, color='Blue')
plt.title(f'{stock} Volume History')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.show()

# %%
import pandas as pd

# %%
ma100=df.Close.rolling(100).mean()

# %%
ma100
# Out:
# Ticker        AAPL
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 3846    230.967733
# 3847    230.616643
# 3848    230.317868
# 3849    230.037725
# 3850    229.773407
#
# [3851 rows x 1 columns]

# %%
ma200=df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close, label=f'{stock} Closing Price', linewidth=1, color='Red') 
plt.plot(ma100, label=f'{stock} 100 Day Moving Average', linewidth=2, color='Yellow') 
plt.plot(ma200, label=f'{stock} 200 Day Moving Average', linewidth=2, color='Green')
plt.title(f'{stock} High Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Expected Price in USD')
plt.legend()
plt.show()

# %%
#TRAINING & TESTING DATA
data_training= pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing= pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

# %%
data_training.shape
# Out:
# (2695, 1)

# %%
data_testing.shape
# Out:
# (1156, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler (feature_range =(0,1))
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array.shape
# Out:
# (2695, 1)

# %%
data_training_array
# Out:
# array([[0.00528434],
#        [0.00537337],
#        [0.00455282],
#        ...,
#        [0.85325862],
#        [0.85466225],
#        [0.82807409]])

# %%
x_train=[]
y_train=[]

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
#LSTM MODEL

from keras.layers import Dense, LSTM, Dropout
from keras.models import Sequential
# Out:
# WARNING:tensorflow:From C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\distributions\distribution.py:259: ReparameterizationType.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\distributions\bernoulli.py:165: RegisterKL.__init__ (from tensorflow.python.ops.distributions.kullback_leibler) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# ...
